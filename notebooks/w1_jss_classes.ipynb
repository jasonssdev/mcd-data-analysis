# %%
# !pwd
# Out:
# /Users/jasonssdev/Dev/Learning/UC/mcd-data-analysis

# %%
from utils.paths import PROJECT_ROOT, DATA_RAW_DIR

# %%
data_path = str(DATA_RAW_DIR / "datos.xls")
print(f"Data path: {data_path}")
# Out:
# Data path: /Users/jasonssdev/Dev/Learning/UC/mcd-data-analysis/data/raw/datos.xls

# %%
import pandas as pd

# %%
df_grd = pd.read_excel(io=data_path, sheet_name="GRD", header=0, index_col=None)
df_grd.head()
# Out:
#   ID GRD    Nombre GRD  Costo resolución en Clínica Privada [MM$]
# 0   GRD1     Coronario                                      7.917
# 1   GRD2      Hepático                                      3.417
# 2   GRD3  Respiratorio                                      2.915
# 3   GRD4         Renal                                      6.188
# 4   GRD5   Neurológico                                      6.782

# %%
df_hospitales = pd.read_excel(io=data_path, sheet_name="Hospitales", header=0, index_col=None)
df_hospitales.head()
# Out:
#                             Nombre Servicio de Salud  \
# 0  Metropolitano Norte                           ...
# 1  Metropolitano Occidente                       ...
# 2  Metropolitano Occidente                       ...
# 3  Metropolitano Occidente                       ...
# 4  Metropolitano Occidente                       ...
#
#                          Nombre Establecimiento  \
# 0                Complejo Hospitalario San José
# 1        Hospital Adalberto Steeger (Talagante)
# 2               Hospital Dr. Félix Bulnes Cerda
# 3                     Hospital San Juan de Dios
# 4  Instituto Traumatológico Dr. Teodoro Gebauer
#
#    Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# 0                                11                                33
# 1                                 6                                11
# 2                                 3                                 6
# ...

# %%
df_informacion_historica = pd.read_excel(io=data_path, sheet_name="Información Histórica", header=0, index_col=None)
df_informacion_historica.head()
# Out:
#    Número de llegada                         Hospital al que llega    GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer   GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán   GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.   GRD7
# 3                  4         Hospital Dr. Exequiel González Cortés  GRD10
# 4                  5                  Hospital Barros Luco Trudeau   GRD6
#
#    Día de llegada  Día de salida  Estadia
# 0               1              4        3
# 1               1              5        4
# 2               1              5        4
# 3               1             11       10
# 4               1              6        5

# %%
df_clase_1 = pd.read_excel(io=data_path, sheet_name="Clase 1", header=0, index_col=None)
df_clase_1.head()
# Out:
#    Dia  Llegada
# 0    1        4
# 1    2        5
# 2    3        5
# 3    4        2
# 4    5        4

# %%
df_hospitales["Nombre Servicio de Salud"].unique()
# Out:
# array(['Metropolitano Norte                               ',
#        'Metropolitano Occidente                           ',
#        'Metropolitano Central                             ',
#        'Metropolitano Oriente                             ',
#        'Metropolitano Sur                                 ',
#        'Metropolitano Sur Oriente                         '], dtype=object)

# %%
# ¿Cuál de las siguientes alternativas indica correctamente el costo máximo diario de atención en el Servicio de Salud Metropolitano?

df_metropolitano = df_hospitales[df_hospitales['Nombre Servicio de Salud'].str.contains("Metropolitano", case=False)]
df_metropolitano.tail()
# Out:
#                              Nombre Servicio de Salud  \
# 16  Metropolitano Sur                             ...
# 17  Metropolitano Sur Oriente                     ...
# 18  Metropolitano Sur Oriente                     ...
# 19  Metropolitano Sur Oriente                     ...
# 20  Metropolitano Sur Oriente                     ...
#
#                         Nombre Establecimiento  \
# 16   Hospital Parroquial de San Bernardo
# 17  Complejo Hospitalario Dr. Sótero del Río
# 18              Hospital Clínico de la Florida
# 19       Hospital Metropolitano ( ex Militar )
# 20  Hospital Padre Alberto Hurtado (San Ramón)
#
#     Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# 16                                 6                                10
# 17                                20                                35
# 18                                 9                                15
# 19                                12                                20
# ...

# %%
grd_columns = [col for col in df_hospitales.columns if "Costo diario GRD" in col]
grd_columns
# Out:
# ['Costo diario GRD1 [MM$]',
#  'Costo diario GRD2 [MM$]',
#  'Costo diario GRD3 [MM$]',
#  'Costo diario GRD4 [MM$]',
#  'Costo diario GRD5 [MM$]',
#  'Costo diario GRD6 [MM$]',
#  'Costo diario GRD7 [MM$]',
#  'Costo diario GRD8 [MM$]',
#  'Costo diario GRD9 [MM$]',
#  'Costo diario GRD10 [MM$]']

# %%
costo_diario = df_metropolitano[grd_columns].max()
costo_diario
# Out:
# Costo diario GRD1 [MM$]     0.593
# Costo diario GRD2 [MM$]     0.599
# Costo diario GRD3 [MM$]     0.590
# Costo diario GRD4 [MM$]     0.594
# Costo diario GRD5 [MM$]     0.597
# Costo diario GRD6 [MM$]     0.595
# Costo diario GRD7 [MM$]     0.584
# Costo diario GRD8 [MM$]     0.572
# Costo diario GRD9 [MM$]     0.590
# Costo diario GRD10 [MM$]    0.574
# dtype: float64

# %%
costo_maximo_grd = costo_diario.idxmax()
costo_maximo_value = costo_diario.max()
print(costo_maximo_grd, costo_maximo_value)
# Out:
# Costo diario GRD2 [MM$] 0.599

# %%
# Estadia informacion historica

df_informacion_historica.columns
# Out:
# Index(['Número de llegada', 'Hospital al que llega', 'GRD', 'Día de llegada',
#        'Día de salida', 'Estadia'],
#       dtype='object')

# %%
df_informacion_historica[['GRD', 'Estadia']].groupby('GRD').mean().sort_values(by='Estadia', ascending=False)
# Out:
#        Estadia
# GRD
# GRD1      10.0
# GRD10     10.0
# GRD4       6.0
# GRD6       5.0
# GRD9       5.0
# GRD2       4.0
# GRD5       4.0
# GRD7       4.0
# GRD8       4.0
# GRD3       3.0

# %%
# Costo de resolucion ordenado

df_grd.columns
# Out:
# Index(['ID GRD', 'Nombre GRD', 'Costo resolución en Clínica Privada [MM$]'], dtype='object')

# %%
df_grd.sort_values(by='Costo resolución en Clínica Privada [MM$]', ascending=False)
# Out:
#   ID GRD      Nombre GRD  Costo resolución en Clínica Privada [MM$]
# 0   GRD1       Coronario                                      7.917
# 9  GRD10      Intestinal                                      7.916
# 4   GRD5     Neurológico                                      6.782
# 7   GRD8   Oftalmológico                                      6.720
# 3   GRD4           Renal                                      6.188
# 8   GRD9    Circulatorio                                      5.524
# 5   GRD6  Traumatológico                                      4.881
# 1   GRD2        Hepático                                      3.417
# 2   GRD3    Respiratorio                                      2.915
# 6   GRD7       Esofágico                                      2.629

# %%
df_hospitales.columns
# Out:
# Index(['Nombre Servicio de Salud', 'Nombre Establecimiento',
#        'Área Cuidados Intensivos Adultos', 'Área Cuidados Intermedios Adulto',
#        'Total Camas Críticas', 'Máxima cantidad de camas a aumetar',
#        'Costo de instalar una cama [MM$]',
#        'Costo de operación anual de una cama [MM$]', 'Costo diario GRD1 [MM$]',
#        'Costo diario GRD2 [MM$]', 'Costo diario GRD3 [MM$]',
#        'Costo diario GRD4 [MM$]', 'Costo diario GRD5 [MM$]',
#        'Costo diario GRD6 [MM$]', 'Costo diario GRD7 [MM$]',
#        'Costo diario GRD8 [MM$]', 'Costo diario GRD9 [MM$]',
#        'Costo diario GRD10 [MM$]'],
#       dtype='object')

# %%
df_hospitales['Área Cuidados Intensivos Adultos'].mean()
# Out:
# np.float64(14.047619047619047)

# %%
# Utilizando Dataframe y comandos de Python, indique ¿cuál de las siguientes alternativas indica correctamente el máximo de camas críticas que hay en total en los Servicios de Salud Metropolitano Sur y Sur Oriente?
camas_criticas_sur_suroriente = df_hospitales[
    (df_hospitales['Nombre Servicio de Salud'] == 'Metropolitano Sur') |
    (df_hospitales['Nombre Servicio de Salud'] == 'Metropolitano Sur Oriente')]
camas_criticas_sur_suroriente
# Out:
# Empty DataFrame
# Columns: [Nombre Servicio de Salud, Nombre Establecimiento, Área Cuidados Intensivos Adultos, Área Cuidados Intermedios Adulto, Total Camas Críticas, Máxima cantidad de camas a aumetar, Costo de instalar una cama [MM$], Costo de operación anual de una cama [MM$], Costo diario GRD1 [MM$], Costo diario GRD2 [MM$], Costo diario GRD3 [MM$], Costo diario GRD4 [MM$], Costo diario GRD5 [MM$], Costo diario GRD6 [MM$], Costo diario GRD7 [MM$], Costo diario GRD8 [MM$], Costo diario GRD9 [MM$], Costo diario GRD10 [MM$]]
# Index: []

# %%
df_hospitales['Nombre Servicio de Salud'].unique()
# Out:
# array(['Metropolitano Norte                               ',
#        'Metropolitano Occidente                           ',
#        'Metropolitano Central                             ',
#        'Metropolitano Oriente                             ',
#        'Metropolitano Sur                                 ',
#        'Metropolitano Sur Oriente                         '], dtype=object)

# %%
df_hospitales['Nombre Servicio de Salud'] = df_hospitales['Nombre Servicio de Salud'].str.strip()

# %%
df_hospitales['Nombre Servicio de Salud'].unique()
# Out:
# array(['Metropolitano Norte', 'Metropolitano Occidente',
#        'Metropolitano Central', 'Metropolitano Oriente',
#        'Metropolitano Sur', 'Metropolitano Sur Oriente'], dtype=object)

# %%
camas_criticas_sur_suroriente = df_hospitales[
    df_hospitales['Nombre Servicio de Salud'].isin(
        ['Metropolitano Sur', 'Metropolitano Sur Oriente'])]
camas_criticas_sur_suroriente
# Out:
#      Nombre Servicio de Salud  \
# 12          Metropolitano Sur
# 13          Metropolitano Sur
# 14          Metropolitano Sur
# 15          Metropolitano Sur
# 16          Metropolitano Sur
# 17  Metropolitano Sur Oriente
# 18  Metropolitano Sur Oriente
# 19  Metropolitano Sur Oriente
# 20  Metropolitano Sur Oriente
#
#                                Nombre Establecimiento  \
# 12                       Hospital Barros Luco Trudeau
# 13  Hospital de Enfermedades Infecciosas Dr. Lucio...
# 14              Hospital Dr. Exequiel González Cortés
# 15                                   Hospital El Pino
# 16          Hospital Parroquial de San Bernardo
# 17         Complejo Hospitalario Dr. Sótero del Río
# 18                     Hospital Clínico de la Florida
# 19              Hospital Metropolitano ( ex Militar )
# 20         Hospital Padre Alberto Hurtado (San Ramón)
#
#     Área Cuidados Intensivos Adultos  Área Cuidados Intermedios Adulto  \
# ...

# %%
camas_criticas_sur_suroriente = df_hospitales[
    df_hospitales['Nombre Servicio de Salud'] ==
    'Metropolitano Sur']['Total Camas Críticas'].max()
camas_criticas_sur_suroriente
# Out:
# 74

# %%
camas_criticas_sur_suroriente = df_hospitales[
    df_hospitales['Nombre Servicio de Salud'] ==
    'Metropolitano Sur Oriente']['Total Camas Críticas'].max()
camas_criticas_sur_suroriente
# Out:
# 55

# %%
# mas facil hubiera sido

camas_criticas_sur_suroriente = df_hospitales[[
    'Nombre Servicio de Salud', 'Total Camas Críticas'
]].groupby('Nombre Servicio de Salud').max()
camas_criticas_sur_suroriente.sort_values(by='Total Camas Críticas', ascending=False)
# Out:
#                            Total Camas Críticas
# Nombre Servicio de Salud
# Metropolitano Occidente                      76
# Metropolitano Sur                            74
# Metropolitano Sur Oriente                    55
# Metropolitano Oriente                        46
# Metropolitano Central                        44
# Metropolitano Norte                          44

# %%
# Utilizando el Dataframe Estadía_promedio_Excel.xlsx y comandos de Python, ¿cuál de las siguientes alternativas corresponde a la máxima estadía promedio de entre los GRDs?

df_informacion_historica.head()
# Out:
#    Número de llegada                         Hospital al que llega    GRD  \
# 0                  1  Instituto Traumatológico Dr. Teodoro Gebauer   GRD3
# 1                  2           Hospital Clínico San Borja-Arriarán   GRD7
# 2                  3                    Hospital Dr. Luis Tisné B.   GRD7
# 3                  4         Hospital Dr. Exequiel González Cortés  GRD10
# 4                  5                  Hospital Barros Luco Trudeau   GRD6
#
#    Día de llegada  Día de salida  Estadia
# 0               1              4        3
# 1               1              5        4
# 2               1              5        4
# 3               1             11       10
# 4               1              6        5

# %%
df_informacion_historica.columns
# Out:
# Index(['Número de llegada', 'Hospital al que llega', 'GRD', 'Día de llegada',
#        'Día de salida', 'Estadia'],
#       dtype='object')

# %%
max_estadia_promedio = df_informacion_historica[[
    'GRD', 'Estadia'
]].groupby('GRD').mean().sort_values(by='Estadia', ascending=False)

max_estadia_promedio
# Out:
#        Estadia
# GRD
# GRD1      10.0
# GRD10     10.0
# GRD4       6.0
# GRD6       5.0
# GRD9       5.0
# GRD2       4.0
# GRD5       4.0
# GRD7       4.0
# GRD8       4.0
# GRD3       3.0

# %%
# Utilizando el archivo “Datos.xls”, un Dataframe y comandos en Python, ¿cuál de las siguientes alternativas corresponde al costo total de instalar el máximo de camas críticas posibles en toda la región?

df_hospitales.columns
# Out:
# Index(['Nombre Servicio de Salud', 'Nombre Establecimiento',
#        'Área Cuidados Intensivos Adultos', 'Área Cuidados Intermedios Adulto',
#        'Total Camas Críticas', 'Máxima cantidad de camas a aumetar',
#        'Costo de instalar una cama [MM$]',
#        'Costo de operación anual de una cama [MM$]', 'Costo diario GRD1 [MM$]',
#        'Costo diario GRD2 [MM$]', 'Costo diario GRD3 [MM$]',
#        'Costo diario GRD4 [MM$]', 'Costo diario GRD5 [MM$]',
#        'Costo diario GRD6 [MM$]', 'Costo diario GRD7 [MM$]',
#        'Costo diario GRD8 [MM$]', 'Costo diario GRD9 [MM$]',
#        'Costo diario GRD10 [MM$]'],
#       dtype='object')

# %%
df_hospitales['costo total de camas a aumentar'] = df_hospitales['Costo de instalar una cama [MM$]'] * df_hospitales['Máxima cantidad de camas a aumetar']
df_hospitales
# Out:
#      Nombre Servicio de Salud  \
# 0         Metropolitano Norte
# 1     Metropolitano Occidente
# 2     Metropolitano Occidente
# 3     Metropolitano Occidente
# 4     Metropolitano Occidente
# 5       Metropolitano Central
# 6       Metropolitano Central
# 7       Metropolitano Central
# 8       Metropolitano Oriente
# 9       Metropolitano Oriente
# 10      Metropolitano Oriente
# 11      Metropolitano Oriente
# 12          Metropolitano Sur
# 13          Metropolitano Sur
# 14          Metropolitano Sur
# 15          Metropolitano Sur
# 16          Metropolitano Sur
# 17  Metropolitano Sur Oriente
# 18  Metropolitano Sur Oriente
# 19  Metropolitano Sur Oriente
# 20  Metropolitano Sur Oriente
#
#                                Nombre Establecimiento  \
# 0                      Complejo Hospitalario San José
# 1              Hospital Adalberto Steeger (Talagante)
# 2                     Hospital Dr. Félix Bulnes Cerda
# 3                           Hospital San Juan de Dios
# ...

# %%
df_hospitales['costo total de camas a aumentar'].sum()
# Out:
# np.int64(240509)
